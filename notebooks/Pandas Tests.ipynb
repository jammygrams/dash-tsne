# %%
import os
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np
import pandas as pd

# %%
def generate_embedding(dataset,
                       iterations,
                       perplexity,
                       pca_dim,
                       learning_rate,
                       verbose=1):
    path = f'../demo_embeddings/{dataset}/iterations_{iterations}/perplexity_{perplexity}/pca_{pca_dim}/learning_rate_{learning_rate}'

    def display(string):
        if verbose:
            print(string)

    if os.path.exists(path):
        if os.path.exists(path + '/data.csv'):
            display(f'{dataset} already exists.')
            return
    else:
        os.makedirs(path)

    data = pd.read_csv(f"../data/{dataset}_input.csv")
    labels = pd.read_csv(f"../data/{dataset}_labels.csv")
    nb_col = data.shape[1]

    pca = PCA(n_components=min(nb_col, pca_dim))
    data_pca = pca.fit_transform(data.values)

    tsne = TSNE(n_components=3,
                n_iter=iterations,
                learning_rate=learning_rate,
                perplexity=perplexity,
                random_state=1131)

    embedding = tsne.fit_transform(data_pca)

    embedding_df = pd.DataFrame(embedding, columns=['x', 'y', 'z'])

    embedding_df.index = labels.values

    embedding_df.to_csv(path + f'/data.csv')

    display(f'{path} has been generated.')

# %%
generate_embedding('mnist_3000', 250, 3, 25, 100, verbose=1)
# Out:
# ../demo_embeddings/mnist_3000/iterations_250/perplexity_3/pca_25/learning_rate_100 has been generated.

# %%
dataset = 'mnist_3000'
iterations = 250
perplexity = 3
pca_dim = 25
learning_rate = 10

path = f'../demo_embeddings/{dataset}/iterations_{iterations}/perplexity_{perplexity}/pca_{pca_dim}/learning_rate_{learning_rate}'

pd.read_csv(path+f'/data.csv', index_col=0)
# Out:
#                 x         y         z
# Digit 2 -3.510562  1.200590  0.391219
# Digit 7  2.870297  0.072102  0.068497
# Digit 1  2.273684  0.787113 -2.629111
# Digit 3 -2.521477 -1.224001 -0.568755
# Digit 5 -0.820209 -1.568849 -0.118886
# Digit 3 -1.747627 -1.494198 -1.203496
# Digit 8 -1.097730 -0.111893 -0.739083
# Digit 6 -0.396200 -1.593683  2.542232
# Digit 7  3.048738  1.239788  0.069429
# Digit 0 -0.196434 -3.815999 -0.114801
# Digit 3 -1.576019 -0.444741 -1.678220
# Digit 3 -2.514223 -0.904610 -0.312582
# Digit 1  0.760435  3.834042 -1.086570
# Digit 2 -2.535851  1.416719  0.826653
# Digit 1  0.373676  4.093334 -0.779782
# Digit 0 -0.388217 -3.282236 -0.518593
# Digit 0  0.235705 -3.461193 -0.300555
# Digit 3 -2.485992 -0.966616 -0.513643
# Digit 9  0.089030  2.152368 -0.275014
# Digit 0 -0.140054 -3.493778 -0.387673
# Digit 0  0.922057 -3.351695 -0.127262
# Digit 7  2.095800 -0.402272  0.784091
# Digit 6  0.410421 -2.266842  2.788423
# Digit 7  2.910872  0.416287  0.145294
# Digit 7  3.007737 -0.196963  0.411537
# Digit 7  3.005138 -0.099056  0.168435
# Digit 0  0.659228 -2.938236 -0.791689
# Digit 8 -1.317715 -1.277883 -1.325519
# Digit 2 -1.199043  1.396733  1.424005
# Digit 0  0.669622 -2.938407 -0.771639
# ...           ...       ...       ...
# Digit 2 -2.914935  1.465567  0.063004
# Digit 6  0.791627 -3.079752  2.004985
# Digit 6  0.427558 -2.636841  2.180103
# Digit 4  0.692212  1.734842 -0.436491
# Digit 0  1.114679 -2.542172 -0.495408
# Digit 4  1.143176  0.538853  1.101358
# Digit 2 -2.128210  1.492404  0.986172
# Digit 3 -1.773836 -1.427088 -1.455935
# Digit 8 -0.935326  0.322352  0.087750
# Digit 7  3.707035  1.483979  0.633713
# Digit 6 -0.745813 -1.213885  1.141709
# Digit 4  1.258709  1.353033  1.212884
# Digit 5 -1.061949  0.484179  2.157890
# Digit 6 -0.655868 -1.547128  2.340710
# Digit 9  1.140178  1.272308 -0.502525
# Digit 5 -0.120820 -0.493422  0.839273
# Digit 2 -2.881688  0.642460  1.083661
# Digit 0  0.608025 -3.174525 -0.447536
# Digit 2 -2.794089  1.463822  0.290478
# Digit 9  1.744973  0.656328 -0.254641
# Digit 1  2.004785  1.284024 -2.288242
# Digit 9  1.480503  1.163651 -0.116596
# Digit 0  0.789503 -2.421968 -0.606089
# Digit 5 -0.997777 -1.422938  0.294562
# Digit 9  0.801541  1.313789 -0.368095
# Digit 5 -0.967363 -0.261873  1.574035
# Digit 3 -2.634013 -1.172330 -1.077479
# Digit 2 -0.157457  0.353453  0.547809
# Digit 6  0.327495 -2.734971  2.018855
# Digit 4  0.416167  2.272273  0.162204
#
# [3000 rows x 3 columns]

# %%
# %timeit df = pd.read_csv("mnist_3000_input.csv")
# %timeit df2 = pd.read_csv('../demo_embeddings/mnist_3000/iterations_250/perplexity_3/pca_25/learning_rate_10/data.csv')
# %timeit combined_df = df.join(df2.loc[:,'x':'z']).set_index(['x','y','z'])
# Out:
# 650 ms ± 62.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.69 ms ± 552 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 116 ms ± 1.38 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df2 = pd.read_csv('../demo_embeddings/mnist_3000/iterations_250/perplexity_3/pca_25/learning_rate_10/data.csv')
df2.head()
# Out:
#   Unnamed: 0         x         y         z
# 0    Digit 2 -3.510562  1.200590  0.391219
# 1    Digit 7  2.870297  0.072102  0.068497
# 2    Digit 1  2.273684  0.787113 -2.629111
# 3    Digit 3 -2.521477 -1.224001 -0.568755
# 4    Digit 5 -0.820209 -1.568849 -0.118886

# %%
image = df.iloc[0]
matrix = image.values.reshape(28,28)

# %%
di = {'x': -3.510562, 'y': 1.200590}
def compare(coord):
    return df2[coord] == di[coord]

print(di['y'])
df2[compare('y')]
# Out:
# 1.20059
# Empty DataFrame
# Columns: [Unnamed: 0, x, y, z]
# Index: []

# %%
hoverData = { "points": [ { "x": 0.86785585, "y": 2.3639283, "z": 1.0667368, "curveNumber": 4, "pointNumber": 171, "text": "Digit 4" } ] }
hover_point_np = np.array([hoverData['points'][0][i] for i in ['x', 'y', 'z']]).astype(np.float64)
hover_point_np
# Out:
# array([0.86785585, 2.3639283 , 1.0667368 ])

# %%
mask = df2.loc[:,'x':'z'].eq(hover_point_np).all(axis=1)
df2[mask].index[0]

image = df.iloc[df2[mask].index[0]].values.reshape(28,28).astype(np.float64)
Image.fromarray(np.uint8(255 * image))
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x1E9A0B1F9B0>

# %%
import base64
from PIL import Image
from io import BytesIO

def numpy_to_b64(array, scalar=True):
    if scalar:
        array = np.uint8(255 * array)
    
    im_pil = Image.fromarray(array)
    buff = BytesIO()
    im_pil.save(buff, format="png")
    im_b64 = base64.b64encode(buff.getvalue()).decode("utf-8")
    
    return im_b64

numpy_to_b64(image)
# Out:
# '...'
